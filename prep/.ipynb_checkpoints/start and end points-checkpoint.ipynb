# %%
import json
from pprint import pprint

data = json.load(open('data.json'))

# %%
points = []
starts = []
ends = []
for line in data['source']['data']['features']:
    if line['geometry']['coordinates'][0] != 'e':
        start = [round(float(line['geometry']['coordinates'][0][0]), 5), round(float(line['geometry']['coordinates'][0][1]), 5)]
        end = [round(float(line['geometry']['coordinates'][len(line['geometry']['coordinates'])-1][0]), 5), round(float(line['geometry']['coordinates'][len(line['geometry']['coordinates'])-1][1]), 5)]
        points.append({
            'start': start,
            'end': end
        })
        starts.append(str(start))
        ends.append(str(end))

# %%
start_data= {}
for s in starts:
    if s in start_data:
        start_data[s] = int(start_data[s]) + 1
    else:
        start_data[s] = 1
# Out:
# {'[-117.15191, 32.71167]': 1,
#  '[-117.19145, 32.72998]': 1,
#  '[-118.36609, 34.0628]': 1,
#  '[-118.39852, 33.94428]': 1,
#  '[-122.16251, 37.445]': 1,
#  '[-122.18956, 47.4359]': 1,
#  '[-122.26839, 37.86934]': 1,
#  '[-122.27731, 47.63628]': 1,
#  '[-122.29345, 47.66154]': 1,
#  '[-122.294, 47.66246]': 1,
#  '[-122.29605, 47.66141]': 1,
#  '[-122.29621, 47.66121]': 1,
#  '[-122.29635, 47.44054]': 6,
#  '[-122.29806, 47.66428]': 1,
#  '[-122.29851, 47.66927]': 1,
#  '[-122.29955, 47.66824]': 1,
#  '[-122.3012, 47.66284]': 1,
#  '[-122.30129, 47.66637]': 1,
#  '[-122.30191, 47.66631]': 1,
#  '[-122.30367, 47.61275]': 1,
#  '[-122.30436, 47.64902]': 2,
#  '[-122.30495, 47.66307]': 1,
#  '[-122.30546, 47.66237]': 1,
#  '[-122.30588, 47.66305]': 8,
#  '[-122.30602, 47.66647]': 1,
#  '[-122.30628, 47.66306]': 1,
#  '[-122.30629, 47.66306]': 6,
#  '[-122.30649, 47.66729]': 1,
#  '[-122.30719, 47.66406]': 1,
#  '[-122.30719, 47.66428]': 15,
#  '[-122.30905, 47.65975]': 1,
#  '[-122.30945, 47.666]': 1,
#  '[-122.3095, 47.66253]': 1,
#  '[-122.30951, 47.66222]': 2,
#  '[-122.30974, 47.66212]': 2,
#  '[-122.31082, 47.66365]': 1,
#  '[-122.31084, 47.6622]': 1,
#  '[-122.31084, 47.66236]': 1,
#  '[-122.31085, 47.66185]': 1,
#  '[-122.31091, 47.65425]': 1,
#  '[-122.31304, 47.66782]': 1,
#  '[-122.31313, 47.66091]': 1,
#  '[-122.31326, 47.65565]': 1,
#  '[-122.31417, 47.67088]': 1,
#  '[-122.3142, 47.66427]': 1,
#  '[-122.31422, 47.66339]': 1,
#  '[-122.31439, 47.65656]': 1,
#  '[-122.31526, 47.65206]': 1,
#  '[-122.31556, 47.65652]': 1,
#  '[-66.05418, 18.40308]': 1,
#  '[-66.05508, 18.40314]': 1,
#  '[-66.05999, 18.45399]': 1,
#  '[-66.07135, 18.4456]': 1,
#  '[-66.07324, 18.45338]': 2,
#  '[-66.07661, 18.44732]': 1,
#  '[-73.75436, 40.65009]': 1,
#  '[-73.95609, 40.63982]': 1,
#  '[23.73357, 37.97349]': 1,
#  '[23.92019, 37.96185]': 1}

# %%
end_data= {}
for e in ends:
    if e in end_data:
        end_data[e] = int(end_data[e]) + 1
    else:
        end_data[e] = 1
# Out:
# {'[-117.16842, 32.72371]': 1,
#  '[-117.22359, 32.71818]': 1,
#  '[-118.36609, 34.0628]': 1,
#  '[-118.39852, 33.94428]': 1,
#  '[-122.14957, 47.5787]': 2,
#  '[-122.21127, 37.71727]': 1,
#  '[-122.25646, 37.56865]': 1,
#  '[-122.26839, 37.86934]': 1,
#  '[-122.28581, 37.54564]': 1,
#  '[-122.29345, 47.66154]': 1,
#  '[-122.29635, 47.44054]': 6,
#  '[-122.29719, 47.66148]': 1,
#  '[-122.29909, 47.66175]': 1,
#  '[-122.30368, 47.65105]': 1,
#  '[-122.30436, 47.64902]': 2,
#  '[-122.30453, 47.65782]': 1,
#  '[-122.30588, 47.66305]': 21,
#  '[-122.30649, 47.66729]': 1,
#  '[-122.30719, 47.66428]': 27,
#  '[-122.30759, 47.65203]': 1,
#  '[-122.309, 47.65122]': 1,
#  '[-122.30974, 47.66212]': 5,
#  '[-122.31084, 47.6622]': 2,
#  '[-122.31304, 47.66815]': 1,
#  '[-122.31305, 47.66671]': 1,
#  '[-122.31313, 47.66092]': 1,
#  '[-122.31417, 47.67088]': 1,
#  '[-122.31589, 47.68443]': 2,
#  '[-122.31633, 47.66687]': 2,
#  '[-122.31639, 47.66293]': 2,
#  '[-122.31642, 47.67497]': 1,
#  '[-122.31677, 47.61088]': 4,
#  '[-122.31718, 47.6853]': 29,
#  '[-122.31756, 47.61413]': 1,
#  '[-122.31781, 47.65753]': 4,
#  '[-122.31814, 47.61447]': 2,
#  '[-122.31945, 47.61422]': 1,
#  '[-122.32026, 47.61296]': 1,
#  '[-122.32342, 37.56753]': 1,
#  '[-122.32465, 47.64145]': 1,
#  '[-122.32504, 47.68101]': 1,
#  '[-122.32545, 47.67569]': 1,
#  '[-122.32582, 47.6152]': 1,
#  '[-122.32779, 47.67834]': 1,
#  '[-122.33141, 47.61164]': 1,
#  '[-122.3326, 47.61191]': 1,
#  '[-122.33315, 47.62726]': 2,
#  '[-122.33323, 47.61142]': 16,
#  '[-122.33389, 47.64686]': 2,
#  '[-122.33434, 47.6225]': 1,
#  '[-122.33451, 47.64661]': 1,
#  '[-122.33516, 47.61019]': 1,
#  '[-122.33576, 47.61251]': 1,
#  '[-122.33673, 37.55928]': 1,
#  '[-122.33848, 47.61833]': 1,
#  '[-122.33856, 47.64805]': 1,
#  '[-122.33863, 47.61343]': 1,
#  '[-122.34406, 47.64917]': 1,
#  '[-122.34413, 47.6131]': 1,
#  '[-122.34448, 47.6488]': 3,
#  '[-122.34457, 47.68209]': 1,
#  '[-122.34813, 47.6636]': 1,
#  '[-122.35002, 47.65924]': 2,
#  '[-122.3513, 47.6501]': 2,
#  '[-122.35285, 47.64778]': 2,
#  '[-122.35413, 47.65216]': 1,
#  '[-122.38723, 47.54406]': 1,
#  '[-122.3936, 37.61537]': 3,
#  '[-122.40685, 37.78895]': 3,
#  '[-122.417, 37.80958]': 1,
#  '[-122.43426, 37.79436]': 1,
#  '[-157.92294, 21.33302]': 1,
#  '[-65.64822, 18.3294]': 2,
#  '[-66.07324, 18.45338]': 3,
#  '[-66.07653, 18.44744]': 1,
#  '[-66.10474, 18.46634]': 1,
#  '[-66.10779, 18.46425]': 1,
#  '[-73.75436, 40.65009]': 1,
#  '[-73.95609, 40.63982]': 1,
#  '[23.73357, 37.97349]': 1,
#  '[23.92019, 37.96185]': 1}

# %%
#1 - 2
print-122.33436226844786- -122.33415842056274
#2 - 3
print -122.33415842056274--122.33436226844786
# Out:
# -0.000203847885118
# 0.000203847885118

# %%
def square(origin):
    longitude = float(origin.split(',')[0][1:])
    latitude = float(origin.split(',')[1][0:-1])
    result = [
        [longitude, latitude],
        [longitude, latitude + 0.00013],
        [longitude - 0.0002, latitude + 0.00013],
        [longitude -0.0002, latitude],
        [longitude, latitude]
    ]
    return result
square('[-122.33335375785828,47.61162776396617]')
# Out:
# [[-122.33335375785828, 47.61162776396617],
#  [-122.33335375785828, 47.61175776396617],
#  [-122.33355375785828, 47.61175776396617],
#  [-122.33355375785828, 47.61162776396617],
#  [-122.33335375785828, 47.61162776396617]]

# %%
start_out = {
   "features": [],
   "type": "FeatureCollection"
}

end_out = {
   "features": [],
   "type": "FeatureCollection"
}

# %%
counter = 0
for z in start_data:
    counter += 1
    start_out['features'].append({
          "type": "Feature",
          "properties": {
             "base_height": 0,
             "height": start_data[z] * 100,
             "color": "#FE872F"
          },
          "geometry": {
            "type": "Polygon",
            "coordinates": [square(z)]
          },
          "id": counter
       })
    
for q in end_data:
    counter += 1
    end_out['features'].append({
          "type": "Feature",
          "properties": {
             "base_height": 0,
             "height": end_data[q] * 100,
             "color": "#5EBA7D"
          },
          "geometry": {
            "type": "Polygon",
            "coordinates": [square(q)]
          },
          "id": counter
       })

import json
with open('start.geojson', 'w') as fp:
    json.dump(start_out, fp)

with open('end.geojson', 'w') as fp:
    json.dump(end_out, fp)
